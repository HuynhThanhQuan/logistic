# %%
restaurant_loc = ['4 Điện Biên Phủ, Đa Kao, Quận 3, Hồ Chí Minh 700000, Vietnam', 
                  '32 Võ Văn Tần, Phường 6, Quận 3, Hồ Chí Minh, Vietnam', 
                  '10 Đặng Tất, Tân Định, Quận 1, Hồ Chí Minh, Vietnam',
                  '252 Điện Biên Phủ, Phường 7, Quận 3, Hồ Chí Minh 700000, Vietnam',
                  '2 Thi Sách, Bến Nghé, Quận 1, Hồ Chí Minh, Vietnam', 
                  '130 Nguyễn Trãi, Phường Phạm Ngũ Lão, Quận 1, Hồ Chí Minh 700000, Vietnam',
                  '21 Hàn Thuyên, Bến Nghé, Quận 1, Hồ Chí Minh, Vietnam',
                  '21 Hoàng Việt, Phường 4, Tân Bình, Hồ Chí Minh 700000, Vietnam']

# %%
time_window = [(0, 10000),
              (0, 3000),
              (0, 3000),
              (0, 5000),
              (0, 8000),
              (0, 9000),
              (0, 7000),
              (0, 10000),]

# %%
depot = 1

# %%
import os
import gmaps
import googlemaps
import argparse
import numpy as np
import json
import time

# %%
# !jupyter nbextension enable --py gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: OK

# %%
gmaps.configure(api_key='AIzaSyAQWqMTOcyLBRDR2skO4F_5QEWzNDOlUHw')
GOOGLE_API = googlemaps.Client(key='AIzaSyAQWqMTOcyLBRDR2skO4F_5QEWzNDOlUHw')
GOOGLE_API

# %%
# Save data into json
json_data = {}
json_data['destination'] = []
for rest in restaurant_loc:
    geocode_res = GOOGLE_API.geocode(rest)
    json_data['destination'].append(geocode_res[0])
json_data['time_window'] = time_window
json_data['depot'] = depot
json.dump(json_data, open('../sample/tsptw.json', 'w'))

# %%
# Load data from json
json_data = json.load(open('../sample/tsptw.json', 'r'))
json_data
# Out:
# {'destination': [{'address_components': [{'long_name': '4',
#      'short_name': '4',
#      'types': ['street_number']},
#     {'long_name': 'Điện Biên Phủ',
#      'short_name': 'Điện Biên Phủ',
#      'types': ['route']},
#     {'long_name': 'Quận 1',
#      'short_name': 'Quận 1',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hồ Chí Minh',
#      'short_name': 'Hồ Chí Minh',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '4 Điện Biên Phủ, Đa Kao, Quận 1, Hồ Chí Minh, Vietnam',
#    'geometry': {'location': {'lat': 10.792602, 'lng': 106.6987296},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 10.7939509802915,
#       'lng': 106.7000785802915},
#      'southwest': {'lat': 10.7912530197085, 'lng': 106.6973806197085}}},
#    'place_id': 'ChIJ7coCZsoodTERjKHYkesTe-Y',
#    'plus_code': {'compound_code': 'QMVX+2F Da Kao, District 1, Ho Chi Minh City, Vietnam',
#     'global_code': '7P28QMVX+2F'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '32',
#      'short_name': '32',
#      'types': ['street_number']},
#     {'long_name': 'Võ Văn Tần',
#      'short_name': 'Võ Văn Tần',
#      'types': ['route']},
#     {'long_name': 'Quận 3',
#      'short_name': 'Quận 3',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hồ Chí Minh',
#      'short_name': 'Hồ Chí Minh',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '32 Võ Văn Tần, Phường 6, Quận 3, Hồ Chí Minh, Vietnam',
#    'geometry': {'bounds': {'northeast': {'lat': 10.7788737, 'lng': 106.692177},
#      'southwest': {'lat': 10.7787483, 'lng': 106.6920451}},
#     'location': {'lat': 10.7788073, 'lng': 106.6921147},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 10.7801599802915,
#       'lng': 106.6934600302915},
#      'southwest': {'lat': 10.7774620197085, 'lng': 106.6907620697085}}},
#    'place_id': 'ChIJ37XanTAvdTERq6X4smRYtLQ',
#    'types': ['premise']},
#   {'address_components': [{'long_name': '10',
#      'short_name': '10',
#      'types': ['street_number']},
#     {'long_name': 'Đặng Tất', 'short_name': 'Đặng Tất', 'types': ['route']},
#     {'long_name': 'Quận 1',
#      'short_name': 'Quận 1',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hồ Chí Minh',
#      'short_name': 'Hồ Chí Minh',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '10 Đặng Tất, Tân Định, Quận 1, Hồ Chí Minh, Vietnam',
#    'geometry': {'bounds': {'northeast': {'lat': 10.793144, 'lng': 106.6890396},
#      'southwest': {'lat': 10.7930157, 'lng': 106.6889655}},
#     'location': {'lat': 10.7930941, 'lng': 106.6889938},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 10.7944288302915,
#       'lng': 106.6903515302915},
#      'southwest': {'lat': 10.7917308697085, 'lng': 106.6876535697085}}},
#    'place_id': 'ChIJbc72ms0odTERHycgYJxC1Qs',
#    'types': ['premise']},
#   {'address_components': [{'long_name': '252',
#      'short_name': '252',
#      'types': ['street_number']},
#     {'long_name': 'Điện Biên Phủ',
#      'short_name': 'Điện Biên Phủ',
#      'types': ['route']},
#     {'long_name': 'Quận 3',
#      'short_name': 'Quận 3',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hồ Chí Minh',
#      'short_name': 'Hồ Chí Minh',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '252 Điện Biên Phủ, Phường 7, Quận 3, Hồ Chí Minh, Vietnam',
#    'geometry': {'location': {'lat': 10.779924, 'lng': 106.68679},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 10.7812729802915,
#       'lng': 106.6881389802915},
#      'southwest': {'lat': 10.7785750197085, 'lng': 106.6854410197085}}},
#    'place_id': 'ChIJYWn17C8vdTERvoidYrp3jKw',
#    'plus_code': {'compound_code': 'QMHP+XP Phường 7, District 3, Ho Chi Minh City, Vietnam',
#     'global_code': '7P28QMHP+XP'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '2',
#      'short_name': '2',
#      'types': ['street_number']},
#     {'long_name': 'Thi Sách', 'short_name': 'Thi Sách', 'types': ['route']},
#     {'long_name': 'Quận 1',
#      'short_name': 'Quận 1',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hồ Chí Minh',
#      'short_name': 'Hồ Chí Minh',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '2 Thi Sách, Bến Nghé, Quận 1, Hồ Chí Minh, Vietnam',
#    'geometry': {'bounds': {'northeast': {'lat': 10.7769735,
#       'lng': 106.7063235},
#      'southwest': {'lat': 10.7766313, 'lng': 106.7060202}},
#     'location': {'lat': 10.7767819, 'lng': 106.7060957},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 10.7781513802915,
#       'lng': 106.7075208302915},
#      'southwest': {'lat': 10.7754534197085, 'lng': 106.7048228697085}}},
#    'place_id': 'ChIJq_sn4UUvdTEReLEikK31e1c',
#    'types': ['premise']},
#   {'address_components': [{'long_name': '130',
#      'short_name': '130',
#      'types': ['street_number']},
#     {'long_name': 'Nguyễn Trãi',
#      'short_name': 'Nguyễn Trãi',
#      'types': ['route']},
#     {'long_name': 'Quận 1',
#      'short_name': 'Quận 1',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hồ Chí Minh',
#      'short_name': 'Hồ Chí Minh',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '130 Nguyễn Trãi, Phường Phạm Ngũ Lão, Quận 1, Hồ Chí Minh, Vietnam',
#    'geometry': {'bounds': {'northeast': {'lat': 10.7698198, 'lng': 106.690816},
#      'southwest': {'lat': 10.7696525, 'lng': 106.6906763}},
#     'location': {'lat': 10.7697034, 'lng': 106.6907673},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 10.7710851302915,
#       'lng': 106.6920951302915},
#      'southwest': {'lat': 10.7683871697085, 'lng': 106.6893971697085}}},
#    'place_id': 'ChIJpwvZCD0vdTERFyVN3q59KQY',
#    'types': ['premise']},
#   {'address_components': [{'long_name': '21',
#      'short_name': '21',
#      'types': ['street_number']},
#     {'long_name': 'Hàn Thuyên',
#      'short_name': 'Hàn Thuyên',
#      'types': ['route']},
#     {'long_name': 'Quận 1',
#      'short_name': 'Quận 1',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hồ Chí Minh',
#      'short_name': 'Hồ Chí Minh',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '21 Hàn Thuyên, Bến Nghé, Quận 1, Hồ Chí Minh, Vietnam',
#    'geometry': {'location': {'lat': 10.7787447, 'lng': 106.6981854},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 10.7800936802915,
#       'lng': 106.6995343802915},
#      'southwest': {'lat': 10.7773957197085, 'lng': 106.6968364197085}}},
#    'place_id': 'ChIJm7Z-jDcvdTERnm8ZFgJnghU',
#    'plus_code': {'compound_code': 'QMHX+F7 Bến Nghé, District 1, Ho Chi Minh City, Vietnam',
#     'global_code': '7P28QMHX+F7'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '21',
#      'short_name': '21',
#      'types': ['street_number']},
#     {'long_name': 'Hoàng Việt',
#      'short_name': 'Hoàng Việt',
#      'types': ['route']},
#     {'long_name': 'Tân Bình',
#      'short_name': 'Tân Bình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hồ Chí Minh',
#      'short_name': 'Hồ Chí Minh',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '21 Hoàng Việt, Phường 4, Tân Bình, Hồ Chí Minh, Vietnam',
#    'geometry': {'location': {'lat': 10.796315, 'lng': 106.66078},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 10.7976639802915,
#       'lng': 106.6621289802915},
#      'southwest': {'lat': 10.7949660197085, 'lng': 106.6594310197085}}},
#    'place_id': 'ChIJU5lx2jMpdTERgJ1iqC37ljE',
#    'plus_code': {'compound_code': 'QMW6+G8 Phường 4, Tan Binh, Ho Chi Minh City, Vietnam',
#     'global_code': '7P28QMW6+G8'},
#    'types': ['street_address']}],
#  'time_window': [[0, 1000],
#   [1000, 3000],
#   [0, 3000],
#   [2000, 5000],
#   [1000, 8000],
#   [5000, 9000],
#   [4000, 7000],
#   [0, 10000]],
#  'depot': 0}
