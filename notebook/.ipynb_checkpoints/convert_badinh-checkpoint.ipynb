# %%
import os
import pandas as pd
import gmaps
import googlemaps
import numpy as np
import json
import time

# %%
gmaps.configure(api_key=os.getenv('GOOGLE_API_KEY'))
GG_CLIENT = googlemaps.Client(key=os.getenv('GOOGLE_API_KEY'))
assert GG_CLIENT is not None, "Please check Google API KEY"

# %%
store_locs = '../data/Location_BaDinh.xlsx'

# %%
df = pd.read_excel(store_locs)

# %%
warehouse = (21.078295, 105.966889)

# %%
lats = [warehouse[0]] + list(df.correct_lat)
lngs = [warehouse[1]] + list(df.correct_lng)

# %%
covered_lat = np.min(lats) + (np.max(lats) - np.min(lats)) / 2
covered_lng = np.min(lngs) + (np.max(lngs) - np.min(lngs)) / 2
covered_lat, covered_lng
# Out:
# (21.051025250000002, 105.8869532)

# %%
layout = {
    'width': "{}px".format(1200),
    'height': "{}px".format(800),}
# Init figure

fig = gmaps.figure(center=(covered_lat, covered_lng), zoom_level=13, layout=layout)

# Plot depot with maker layer
locations = list(zip(df.correct_lat, df.correct_lng))
symbol_layer = gmaps.symbol_layer(locations, fill_color='red', stroke_color='red', scale=3)
marker_layer = gmaps.marker_layer([warehouse])
fig.add_layer(symbol_layer)
fig.add_layer(marker_layer)

# %%
locs = list(zip(lats, lngs))
locs[:5]
# Out:
# [(21.078295, 105.966889),
#  (21.027593, 105.82379),
#  (21.0467195, 105.8072527),
#  (21.0271642, 105.8225908),
#  (21.0291707, 105.8073247)]

# %%
sample = json.load(open('../data/tw_data/data_15_2.txt', 'r'))

# %%
def generate_tw(json_data):
    time_window = list(zip(json_data['ET_i'], json_data['LT_i']))
    time_window = time_window[-1:] + time_window[1:-1]
    idx_ = json_data['Location']
    idx_ = np.array(idx_) + 1
    idx_ = [0] + idx_.tolist()
    return idx_, time_window

# %%
stores, tws = generate_tw(sample)

# %%
stores, tws
# Out:
# ([0, 4, 5, 6, 7, 15, 17, 18, 20, 25, 26, 28, 29, 30, 31, 33],
#  [(0, 10000),
#   (90, 270),
#   (180, 360),
#   (150, 330),
#   (210, 390),
#   (90, 180),
#   (120, 210),
#   (210, 300),
#   (210, 390),
#   (30, 210),
#   (210, 390),
#   (30, 210),
#   (0, 90),
#   (210, 300),
#   (180, 360),
#   (90, 180)])

# %%
locations = [locs[i] for i in stores]
locations
# Out:
# [(21.078295, 105.966889),
#  (21.0291707, 105.8073247),
#  (21.0427522, 105.808253),
#  (21.0237555, 105.8171405),
#  (21.038003, 105.810641),
#  (21.048936, 105.841036),
#  (21.0435847, 105.8465317),
#  (21.0406761, 105.8070174),
#  (21.0348907, 105.8253889),
#  (21.0415455, 105.840011),
#  (21.0360361, 105.8104245),
#  (21.041958, 105.810829),
#  (21.0457791, 105.8115146),
#  (21.0272468, 105.814508),
#  (21.037676, 105.808576),
#  (21.0460733, 105.8464226)]

# %%
# Save data into json
json_data = {}
json_data['destination'] = []
depot = 0
for latlng in locations:
    geocode_res = GG_CLIENT.reverse_geocode(latlng)
    json_data['destination'].append(geocode_res[0])
json_data['time_window'] = tws
json_data['depot'] = depot
json_data['metadata'] = {}
json.dump(json_data, open('./badinh_tsptw.json', 'w'))

# %%
# Load data from json
json_data = json.load(open('./badinh_tsptw.json', 'r'))
json_data
# Out:
# {'destination': [{'address_components': [{'long_name': 'Số 1',
#      'short_name': 'Số 1',
#      'types': ['street_number']},
#     {'long_name': 'Đường Hữu Nghị',
#      'short_name': 'Đường Hữu Nghị',
#      'types': ['route']},
#     {'long_name': 'Thị xã Từ Sơn',
#      'short_name': 'Tx. Từ Sơn',
#      'types': ['locality', 'political']},
#     {'long_name': 'Bắc Ninh',
#      'short_name': 'Bắc Ninh',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Số 1 Đường Hữu Nghị, Phù Chẩn, Từ Sơn, Bắc Ninh, Vietnam',
#    'geometry': {'location': {'lat': 21.0782946, 'lng': 105.967074},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0796435802915,
#       'lng': 105.9684229802915},
#      'southwest': {'lat': 21.0769456197085, 'lng': 105.9657250197085}}},
#    'place_id': 'ChIJ6V7zeTWpNTERvCUI7JBMHG0',
#    'plus_code': {'compound_code': '3XH8+8R Từ Sơn, Bac Ninh Province, Vietnam',
#     'global_code': '7PH73XH8+8R'},
#    'types': ['establishment', 'point_of_interest']},
#   {'address_components': [{'long_name': '645',
#      'short_name': '645',
#      'types': ['street_number']},
#     {'long_name': 'Kim Mã', 'short_name': 'Kim Mã', 'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '645 Kim Mã, Ngọc Khánh, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.0291783, 'lng': 105.8073084},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0305272802915,
#       'lng': 105.8086573802915},
#      'southwest': {'lat': 21.0278293197085, 'lng': 105.8059594197085}}},
#    'place_id': 'ChIJZRq8NJirNTER1vb2bLo2byU',
#    'plus_code': {'compound_code': '2RH4+MW Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RH4+MW'},
#    'types': ['establishment', 'food', 'point_of_interest', 'restaurant']},
#   {'address_components': [{'long_name': 'Ngõ 462 - Bưởi',
#      'short_name': 'Ngõ 462 - Bưởi',
#      'types': ['route']},
#     {'long_name': 'Khu tập thể 7.2 ha',
#      'short_name': 'Khu tập thể 7.2 ha',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Ngõ 462 - Bưởi, Vĩnh Phú, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'bounds': {'northeast': {'lat': 21.0429069, 'lng': 105.808558},
#      'southwest': {'lat': 21.0428683, 'lng': 105.808257}},
#     'location': {'lat': 21.0428876, 'lng': 105.8084075},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 21.0442365802915,
#       'lng': 105.8097564802915},
#      'southwest': {'lat': 21.0415386197085, 'lng': 105.8070585197085}}},
#    'place_id': 'ChIJ_bG9-BarNTERLpKglzUI74w',
#    'types': ['route']},
#   {'address_components': [{'long_name': '575',
#      'short_name': '575',
#      'types': ['street_number']},
#     {'long_name': 'Đường La Thành',
#      'short_name': 'Đường La Thành',
#      'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '575 Đường La Thành, Thành Công, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.0237555, 'lng': 105.8171405},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0251044802915,
#       'lng': 105.8184894802915},
#      'southwest': {'lat': 21.0224065197085, 'lng': 105.8157915197085}}},
#    'place_id': 'ChIJec6332-rNTERHQ5gwuktOFQ',
#    'plus_code': {'compound_code': '2RF8+GV Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RF8+GV'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '443',
#      'short_name': '443',
#      'types': ['street_number']},
#     {'long_name': 'Đội Cấn', 'short_name': 'Đội Cấn', 'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '443 Đội Cấn, Vĩnh Phú, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.038003, 'lng': 105.810641},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0393519802915,
#       'lng': 105.8119899802915},
#      'southwest': {'lat': 21.0366540197085, 'lng': 105.8092920197085}}},
#    'place_id': 'ChIJuRJQZRSrNTEReg0mQuqcRQ0',
#    'plus_code': {'compound_code': '2RQ6+67 Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RQ6+67'},
#    'types': ['convenience_store',
#     'establishment',
#     'food',
#     'point_of_interest',
#     'store']},
#   {'address_components': [{'long_name': '47',
#      'short_name': '47',
#      'types': ['street_number']},
#     {'long_name': 'Phó Đức Chính',
#      'short_name': 'Phó Đức Chính',
#      'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '47 Phó Đức Chính, Trúc Bạch, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.048936, 'lng': 105.841036},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0502849802915,
#       'lng': 105.8423849802915},
#      'southwest': {'lat': 21.0475870197085, 'lng': 105.8396870197085}}},
#    'place_id': 'ChIJf1_eAbKrNTERqoQbYT3l3lg',
#    'plus_code': {'compound_code': '2RXR+HC Truc Bach, Ba Đình, Hanoi, Vietnam',
#     'global_code': '7PH72RXR+HC'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '55',
#      'short_name': '55',
#      'types': ['street_number']},
#     {'long_name': 'Nguyễn Khắc Nhu',
#      'short_name': 'Nguyễn Khắc Nhu',
#      'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '55 Nguyễn Khắc Nhu, Nguyễn Trung Trực, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.0435832, 'lng': 105.84652},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0449321802915,
#       'lng': 105.8478689802915},
#      'southwest': {'lat': 21.0422342197085, 'lng': 105.8451710197085}}},
#    'place_id': 'ChIJPbcTs7CrNTERMXbVsc0EKgA',
#    'plus_code': {'compound_code': '2RVW+CJ Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RVW+CJ'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '376',
#      'short_name': '376',
#      'types': ['street_number']},
#     {'long_name': 'Đường Bưởi',
#      'short_name': 'Đường Bưởi',
#      'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '376 Đường Bưởi, Nghĩa Đô, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.0406761, 'lng': 105.8070174},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.04202508029151,
#       'lng': 105.8083663802915},
#      'southwest': {'lat': 21.0393271197085, 'lng': 105.8056684197085}}},
#    'place_id': 'ChIJe0qGOZGrNTERCsZzUgWMmwE',
#    'plus_code': {'compound_code': '2RR4+7R Nghia Do, Cầu Giấy, Hanoi, Vietnam',
#     'global_code': '7PH72RR4+7R'},
#    'types': ['establishment', 'point_of_interest', 'store']},
#   {'address_components': [{'long_name': '133A',
#      'short_name': '133A',
#      'types': ['street_number']},
#     {'long_name': 'Đội Cấn', 'short_name': 'Đội Cấn', 'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '133A Đội Cấn, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.034915, 'lng': 105.825399},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0362639802915,
#       'lng': 105.8267479802915},
#      'southwest': {'lat': 21.0335660197085, 'lng': 105.8240500197085}}},
#    'place_id': 'ChIJhRYNGgurNTERZ60JbMC_TgQ',
#    'plus_code': {'compound_code': '2RMG+X5 Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RMG+X5'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '18B',
#      'short_name': '18B',
#      'types': ['street_number']},
#     {'long_name': 'Nguyễn Biểu',
#      'short_name': 'Nguyễn Biểu',
#      'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '18B Nguyễn Biểu, Quán Thánh, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.0415455, 'lng': 105.840011},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0428944802915,
#       'lng': 105.8413599802915},
#      'southwest': {'lat': 21.0401965197085, 'lng': 105.8386620197085}}},
#    'place_id': 'ChIJ32aEN6WrNTERlaJRR4KfrmA',
#    'plus_code': {'compound_code': '2RRR+J2 Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RRR+J2'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '38',
#      'short_name': '38',
#      'types': ['street_number']},
#     {'long_name': 'Linh Lang', 'short_name': 'Linh Lang', 'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '38 Linh Lang, Cống Vị, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.0360361, 'lng': 105.8104245},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0373850802915,
#       'lng': 105.8117734802915},
#      'southwest': {'lat': 21.0346871197085, 'lng': 105.8090755197085}}},
#    'place_id': 'ChIJjXs2lhSrNTERO1JbEjcdojg',
#    'plus_code': {'compound_code': '2RP6+C5 Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RP6+C5'},
#    'types': ['convenience_store',
#     'establishment',
#     'food',
#     'point_of_interest',
#     'store']},
#   {'address_components': [{'long_name': '6',
#      'short_name': '6',
#      'types': ['street_number']},
#     {'long_name': 'Đội Nhân', 'short_name': 'Đội Nhân', 'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '6 Đội Nhân, Vĩnh Phú, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.041958, 'lng': 105.810829},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0433069802915,
#       'lng': 105.8121779802915},
#      'southwest': {'lat': 21.0406090197085, 'lng': 105.8094800197085}}},
#    'place_id': 'ChIJ-ezayBarNTERaa-cbznmazM',
#    'plus_code': {'compound_code': '2RR6+Q8 Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RR6+Q8'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '500',
#      'short_name': '500',
#      'types': ['street_number']},
#     {'long_name': 'Hoàng Hoa Thám',
#      'short_name': 'Hoàng Hoa Thám',
#      'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '500 Hoàng Hoa Thám, Vĩnh Phú, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.04574, 'lng': 105.811528},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0470889802915,
#       'lng': 105.8128769802915},
#      'southwest': {'lat': 21.0443910197085, 'lng': 105.8101790197085}}},
#    'place_id': 'ChIJDWweqxCrNTERaQ16VaKzaRk',
#    'plus_code': {'compound_code': '2RW6+7J Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RW6+7J'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '29a',
#      'short_name': '29a',
#      'types': ['street_number']},
#     {'long_name': 'Nguyễn Công Hoan',
#      'short_name': 'Nguyễn Công Hoan',
#      'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '29a Nguyễn Công Hoan, Giảng Võ, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.0272468, 'lng': 105.814508},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0285957802915,
#       'lng': 105.8158569802915},
#      'southwest': {'lat': 21.0258978197085, 'lng': 105.8131590197085}}},
#    'place_id': 'ChIJF5M2Ym6rNTERYMiqXf0YCHg',
#    'plus_code': {'compound_code': '2RG7+VR Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RG7+VR'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '502',
#      'short_name': '502',
#      'types': ['street_number']},
#     {'long_name': 'Đội Cấn', 'short_name': 'Đội Cấn', 'types': ['route']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '502 Đội Cấn, Cống Vị, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.037676, 'lng': 105.808615},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0390249802915,
#       'lng': 105.8099639802915},
#      'southwest': {'lat': 21.03632701970849, 'lng': 105.8072660197085}}},
#    'place_id': 'ChIJe8EcVRSrNTERlIh549wUefQ',
#    'plus_code': {'compound_code': '2RQ5+3C Hanoi, Hoàn Kiếm, Hanoi, Vietnam',
#     'global_code': '7PH72RQ5+3C'},
#    'types': ['street_address']},
#   {'address_components': [{'long_name': '33',
#      'short_name': '33',
#      'types': ['street_number']},
#     {'long_name': 'Tân Ấp', 'short_name': 'Tân Ấp', 'types': ['route']},
#     {'long_name': 'Ấp Thạnh Vinh',
#      'short_name': 'Ấp Thạnh Vinh',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Ba Đình',
#      'short_name': 'Ba Đình',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Hà Nội',
#      'short_name': 'Hà Nội',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Vietnam',
#      'short_name': 'VN',
#      'types': ['country', 'political']}],
#    'formatted_address': '33 Tân Ấp, Phúc xá, Ba Đình, Hà Nội, Vietnam',
#    'geometry': {'location': {'lat': 21.0460796, 'lng': 105.8464855},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 21.0474285802915,
#       'lng': 105.8478344802915},
#      'southwest': {'lat': 21.0447306197085, 'lng': 105.8451365197085}}},
#    'place_id': 'ChIJeS4ELbGrNTERVl_UCgmF63M',
#    'plus_code': {'compound_code': '2RWW+CH Phuc Xa, Ba Đình, Hanoi, Vietnam',
#     'global_code': '7PH72RWW+CH'},
#    'types': ['establishment', 'point_of_interest']}],
#  'time_window': [[0, 10000],
#   [90, 270],
#   [180, 360],
#   [150, 330],
#   [210, 390],
#   [90, 180],
#   [120, 210],
#   [210, 300],
#   [210, 390],
#   [30, 210],
#   [210, 390],
#   [30, 210],
#   [0, 90],
#   [210, 300],
#   [180, 360],
#   [90, 180]],
#  'depot': 0}
